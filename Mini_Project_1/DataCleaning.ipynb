# %%
# Ruth Gashahun
import pandas as pd
import numpy as np

university = pd.DataFrame({
"student_id":[201,202,203,204,205,206,207,208,209,210],
"name":
["Abel","Sara",None,"John","Marta",None,"David","Helen","Tom",None],
"department":["CS","IT","CS",None,"SE","IT","SE",None,"CS","IT"],
"gpa":[3.5,3.8,np.nan,2.9,3.7,np.nan,3.2,3.4,3.9,np.nan],
"scholarship":
[5000,np.nan,3000,2000,np.nan,4000,3500,np.nan,5000,np.nan]
})

# %%
print("Missing values per column:", university.isnull().sum())
print("Total mising values:", university.isnull().sum().sum())
print("Missing Values Percentage:", (university.isnull().sum() / len(university)) * 100)
# Out:
# Missing values per column: student_id     0
# name           3
# department     2
# gpa            3
# scholarship    4
# dtype: int64
# Total mising values: 12
# Missing Values Percentage: student_id      0.0
# name           30.0
# department     20.0
# gpa            30.0
# scholarship    40.0
# dtype: float64

# %%
# Filling missing value of name by Unknown
university["name"] = university["name"].fillna("Unknown")

# Replacing missing value of department by the mode
university["department"] = university["department"].fillna(university["department"].mode()[0])

# Replacing missing value of gpa by the median
university["gpa"] = university["gpa"].fillna(university["gpa"].median())

# Filling missing value of scholarship by 0
university["scholarship"] = university["scholarship"].fillna(0)

# %%
university
# Out:
#    student_id     name department  gpa  scholarship
# 0         201     Abel         CS  3.5       5000.0
# 1         202     Sara         IT  3.8          0.0
# 2         203  Unknown         CS  3.5       3000.0
# 3         204     John         CS  2.9       2000.0
# 4         205    Marta         SE  3.7          0.0
# 5         206  Unknown         IT  3.5       4000.0
# 6         207    David         SE  3.2       3500.0
# 7         208    Helen         CS  3.4          0.0
# 8         209      Tom         CS  3.9       5000.0
# 9         210  Unknown         IT  3.5          0.0
