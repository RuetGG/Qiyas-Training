# %%
import numpy as np

# %%
arr = np.array([10, 20, 30, 40])
arr.dtype
# Out:
# dtype('int64')

# %%
arr = np.array([1.5, 2.5, 3.5])
arr.dtype
# Out:
# dtype('float64')

# %%
arr = np.array(["Abebe", "Beso", "Bela"])
arr.dtype
# Out:
# dtype('<U5')

# %%
arr = np.array([1, 2, 3, 4], dtype=np.int32)
arr.dtype
# Out:
# dtype('int32')

# %%
arr = np.array([1.5, 2.5, 3.5], dtype=np.float32)
arr.dtype
# Out:
# dtype('float32')

# %%
arr = np.array([1, 2, 3, 4])
new_arr = arr.astype(float)
print(new_arr)
print(arr.nbytes)
# Out:
# array([1., 2., 3., 4.])

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
print(arr.shape)
print(arr.size)
# Out:
# (2, 3)
# 6
