# %%
import pandas as pd
import numpy as np

# %%
courses = ["Python", "Data Science", "Machine Learning", "Deep Learning"]
df = pd.DataFrame(courses)
print(df)
# Out:
#                   0
# 0            Python
# 1      Data Science
# 2  Machine Learning
# 3     Deep Learning

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "Los Angeles", "Chicago"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
data = {
    "Name": ["Abel", "Bob", "Charlie"],
    "Department": ["IS", "CS", "Statistics"],
    "Year": [3, 2, 4]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Department  Year
# 0     Abel          IS     3
# 1      Bob          CS     2
# 2  Charlie  Statistics     4

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Salary": [70000, 80000, 90000],
}
df = pd.DataFrame(data)
print(df)

df.to_csv("test1.csv")
# Out:
#       Name  Salary
# 0    Alice   70000
# 1      Bob   80000
# 2  Charlie   90000

# %%
data = {
    "Name": ["Abel", "Bob", "Charlie"],
}
df = pd.DataFrame(data, index=["S1", "S2", "S3"])
print(df)
# Out:
#        Name
# S1     Abel
# S2      Bob
# S3  Charlie
