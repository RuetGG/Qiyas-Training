# %%
import pandas as pd

# %%
df = pd.read_csv("test1.csv")
# print(df["Name"])
print(df[["Name", "Salary"]])
# Out:
#       Name  Salary
# 0    Alice   70000
# 1      Bob   80000
# 2  Charlie   90000

# %%
df["CGPA"] = [3.5, 3.8, 4.0]
print(df)
# Why does it add new index
# Out:
#    Unnamed: 0     Name  Salary  CGPA
# 0           0    Alice   70000   3.5
# 1           1      Bob   80000   3.8
# 2           2  Charlie   90000   4.0

# %%
df.rename(columns={"CGPA": "GPA"}, inplace=True)
print(df)
# Out:
#    Unnamed: 0     Name  Salary  GPA
# 0           0    Alice   70000  3.5
# 1           1      Bob   80000  3.8
# 2           2  Charlie   90000  4.0

# %%
df.drop("GPA", axis=1, inplace=True)
print(df)
# Out:
#    Unnamed: 0     Name  Salary
# 0           0    Alice   70000
# 1           1      Bob   80000
# 2           2  Charlie   90000

# %%
df.index = [101, 102, 103]
# print(df.loc[102])
# print(df.loc[[101, 103]])

# print(df.iloc[0])
# print(df.iloc[1:])
# print(df.iloc[0,0])
# Out:
# 0
